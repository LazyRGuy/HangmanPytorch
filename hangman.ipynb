# %% [markdown]
# The basic algorithm will match the provided masked string (e.g. a _ _ l e) to all possible words in the dictionary, tabulate the frequency of letters appearing in these possible words, and then guess the letter with the highest frequency of appearence that has not already been guessed. If there are no remaining words that match then it will default back to the character frequency distribution of the entire dictionary.
#
# This benchmark strategy is successful approximately 18% of the time. Your task is to design an algorithm that significantly outperforms this benchmark.

# %%
import json
import requests
import random
import string
import secrets
import time
import re
import collections

try:
    from urllib.parse import parse_qs, urlencode, urlparse
except ImportError:
    from urlparse import parse_qs, urlparse
    from urllib import urlencode

# %%
# Read the words from the file
with open('words_250000_train.txt', 'r') as file:
    word_list = file.read().splitlines()
longest_word = max(word_list,key=len)
print("The longest word is:", longest_word)
print(len(longest_word))
# Out:
# The longest word is: cyclotrimethylenetrinitramine
# 29

# %% [markdown]
# ### Thinking Process
# I could think of 2 approaches for this problem, one was using reinforcement learning to learn using a given environment via some RL algorithm and the second was to use imitation learning (akin to supervised learning).
# We first analyze the first approach.

# %% [markdown]
# #### Approach 1
# I created a custom environment to play hangman (as written below) and trained the PPO algorithm with LSTM support.
# To check the feasibility of the approach, i trained the algorithm for 10000 timesteps while keeping the word to be guessed same (rabbit).

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from tqdm.notebook import tqdm

class HangmanEnv1(gym.Env):
    metadata = {"render_modes": ["human"], "render_fps": 30}
    def __init__(self, word_list,render_mode="human",rword=True):
        super(HangmanEnv1, self).__init__()
        self.word_list = word_list
        self.word = None
        self.obscured_word = None
        self.guessed_letters = set()
        self.tries_remaining = None
        self.rword = rword
        self.action_space = spaces.Discrete(26)  # Guessing a letter
        num_values = np.array([28 for _ in range(29)] + [2 for _ in range(26)] + [7])
        self.observation_space = spaces.MultiDiscrete(num_values)

    def reset(self,seed=None,options=None):
        if self.rword:
            self.word = np.random.choice(self.word_list)
        else:
            self.word = "rabbit"
        self.obscured_word = ['_' for _ in self.word]
        self.guessed_letters = set()
        self.tries_remaining = 6
        return self._get_observation(),{}

    def step(self, action):
        guess = chr(action + ord('a'))
        if guess not in self.guessed_letters:
            self.guessed_letters.add(guess)
        else:
            return self._get_observation(),-3,False,False,{}
        
        if guess in self.word:
            reward = 0
            for i in range(len(self.word)):
                if(self.word[i] == guess):
                    self.obscured_word[i] = guess
            if '_' not in self.obscured_word:
                return self._get_observation(),5,True,False,{}
            else:
                return self._get_observation(),2,False,False,{}
        else:
            self.tries_remaining -= 1
            if self.tries_remaining == 0:
                return self._get_observation(),-2,True,False,{}
            else:
                return self._get_observation(),-1,False,False,{}

    def _get_observation(self):
        return np.array([ord(c) - ord('a') if c != '_' else 26 for c in self.obscured_word]+[27 for _ in range(29-len(self.obscured_word))]
                +[1 if chr(c + ord('a')) in self.guessed_letters else 0 for c in range(26)]+
                [self.tries_remaining])
    def render(self):
        x = 10
    
def accuracy_fn(model,env,verbose=False):
    success = 0
    trr = 0
    progbar = tqdm(range(10000))
    for e in progbar:
        state,_ = env.reset()
        done = False
        tr = 0
        ep_len = 0
        while not done:
            action,_ = model.predict(state)
            next_state, reward, done,oo,bhoo = env.step(action)
            state = next_state
            tr += reward
            ep_len += 1
            if(reward > 0 and done):
                success+=1
            if verbose:
                print(env.word,env.guessed_letters)
        trr += tr/ep_len
    return success/100,trr
# Out:
# 2024-06-29 19:34:24.287847: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-29 19:34:24.571390: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-29 19:34:25.296807: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
env = HangmanEnv1(word_list,rword=False)
model = PPO("MlpPolicy",env,verbose=1)
model.learn(total_timesteps=10000)
model.save("ppo_rabbit")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 env = HangmanEnv1(word_list,rword=False)
#       2 model = PPO("MlpPolicy",env,verbose=1)
# ----> 3 model.learn(total_timesteps=10000)
#       4 model.save("ppo_rabbit")
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:315, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306 def learn(
#     307     self: SelfPPO,
#     308     total_timesteps: int,
#    (...)
#     313     progress_bar: bool = False,
#     314 ) -> SelfPPO:
# --> 315     return super().learn(
#     316         total_timesteps=total_timesteps,
#     317         callback=callback,
#     318         log_interval=log_interval,
#     319         tb_log_name=tb_log_name,
#     320         reset_num_timesteps=reset_num_timesteps,
#     321         progress_bar=progress_bar,
#     322     )
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:300, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     297 assert self.env is not None
#     299 while self.num_timesteps < total_timesteps:
# --> 300     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     302     if not continue_training:
#     303         break
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:179, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176 with th.no_grad():
#     177     # Convert to pytorch tensor or to TensorDict
#     178     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 179     actions, values, log_probs = self.policy(obs_tensor)
#     180 actions = actions.cpu().numpy()
#     182 # Rescale and perform action
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/policies.py:645, in ActorCriticPolicy.forward(self, obs, deterministic)
#     637 """
#     638 Forward pass in all the networks (actor and critic)
#     639
#    (...)
#     642 :return: action, value and log probability of the action
#     643 """
#     644 # Preprocess the observation if needed
# --> 645 features = self.extract_features(obs)
#     646 if self.share_features_extractor:
#     647     latent_pi, latent_vf = self.mlp_extractor(features)
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/policies.py:672, in ActorCriticPolicy.extract_features(self, obs, features_extractor)
#     663 """
#     664 Preprocess the observation if needed and extract features.
#     665
#    (...)
#     669     features for the actor and the features for the critic.
#     670 """
#     671 if self.share_features_extractor:
# --> 672     return super().extract_features(obs, self.features_extractor if features_extractor is None else features_extractor)
#     673 else:
#     674     if features_extractor is not None:
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/policies.py:130, in BaseModel.extract_features(self, obs, features_extractor)
#     122 def extract_features(self, obs: PyTorchObs, features_extractor: BaseFeaturesExtractor) -> th.Tensor:
#     123     """
#     124     Preprocess the observation if needed and extract features.
#     125
#    (...)
#     128     :return: The extracted features
#     129     """
# --> 130     preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
#     131     return features_extractor(preprocessed_obs)
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/preprocessing.py:130, in preprocess_obs(obs, observation_space, normalize_images)
#     125     return F.one_hot(obs.long(), num_classes=int(observation_space.n)).float()
#     127 elif isinstance(observation_space, spaces.MultiDiscrete):
#     128     # Tensor concatenation of one hot encodings of each Categorical sub-space
#     129     return th.cat(
# --> 130         [
#     131             F.one_hot(obs_.long(), num_classes=int(observation_space.nvec[idx])).float()
#     132             for idx, obs_ in enumerate(th.split(obs.long(), 1, dim=1))
#     133         ],
#     134         dim=-1,
#     135     ).view(obs.shape[0], sum(observation_space.nvec))
#     137 elif isinstance(observation_space, spaces.MultiBinary):
#     138     return obs.float()
#
# File ~/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/preprocessing.py:131, in <listcomp>(.0)
#     125     return F.one_hot(obs.long(), num_classes=int(observation_space.n)).float()
#     127 elif isinstance(observation_space, spaces.MultiDiscrete):
#     128     # Tensor concatenation of one hot encodings of each Categorical sub-space
#     129     return th.cat(
#     130         [
# --> 131             F.one_hot(obs_.long(), num_classes=int(observation_space.nvec[idx])).float()
#     132             for idx, obs_ in enumerate(th.split(obs.long(), 1, dim=1))
#     133         ],
#     134         dim=-1,
#     135     ).view(obs.shape[0], sum(observation_space.nvec))
#     137 elif isinstance(observation_space, spaces.MultiBinary):
#     138     return obs.float()
#
# KeyboardInterrupt:

# %%
model_rabbit = PPO.load("ppo_rabbit",env)
percentage,mean_reward = accuracy_fn(model,env)
print("Success rate:",percentage)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Success rate: 6.07

# %% [markdown]
# As you can see by means of the above cell the performance of the model is not admissible and is even lesser than the benchmark. So we conclude that this approach is not feasible.

# %%
# Create the Hangman environment
env1 = HangmanEnv1(word_list)
# Train the agent using PPO
model = PPO("MlpPolicy", env1,verbose=1)
model.learn(total_timesteps=5000000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10.3     |
# |    ep_rew_mean     | -7.58    |
# | time/              |          |
# |    fps             | 198      |
# |    iterations      | 1        |
# |    time_elapsed    | 10       |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10.9         |
# |    ep_rew_mean          | -7.66        |
# | time/                   |              |
# |    fps                  | 170          |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0133686215 |
# |    clip_fraction        | 0.127        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.00429      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0269      |
# |    value_loss           | 12.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | -7.37       |
# | time/                   |             |
# |    fps                  | 163         |
# |    iterations           | 3           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009875486 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.0728      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.85        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.76        |
# |    ep_rew_mean          | -6.78       |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 4           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010443278 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.87        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 8.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | -6.95       |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 5           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011786277 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.076       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.5         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0342     |
# |    value_loss           | 6.82        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.91        |
# |    ep_rew_mean          | -5.63       |
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 6           |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012911666 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0405     |
# |    value_loss           | 7.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | -4.91       |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 7           |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013544347 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.2        |
# |    explained_variance   | 0.0458      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 6.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | -5.53       |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 8           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012908973 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.0429      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 6.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.87        |
# |    ep_rew_mean          | -5.41       |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 9           |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015345143 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.16       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 6.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.78        |
# |    ep_rew_mean          | -4.94       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 10          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014699377 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.053       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 7.53        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.71        |
# |    ep_rew_mean          | -4.23       |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 11          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015414957 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.95        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0525     |
# |    value_loss           | 6.86        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.99        |
# |    ep_rew_mean          | -4.52       |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 12          |
# |    time_elapsed         | 168         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.016508617 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.0165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0547     |
# |    value_loss           | 5.62        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.1        |
# |    ep_rew_mean          | -3.94       |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 13          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.018213423 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0544     |
# |    value_loss           | 6.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -4.38       |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 14          |
# |    time_elapsed         | 197         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.016399706 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.0511      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0529     |
# |    value_loss           | 6.12        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | -4.2       |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 15         |
# |    time_elapsed         | 210        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01772325 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.0372     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.19       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0569    |
# |    value_loss           | 5.79       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | -3.6        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 16          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.020697754 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | -0.0523     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0555     |
# |    value_loss           | 5.74        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.4       |
# |    ep_rew_mean          | -2.46      |
# | time/                   |            |
# |    fps                  | 148        |
# |    iterations           | 17         |
# |    time_elapsed         | 234        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.01860624 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | -0.0142    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.04       |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.06      |
# |    value_loss           | 6.21       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.2        |
# |    ep_rew_mean          | -3.02       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 18          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020087535 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.0604      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0576     |
# |    value_loss           | 6.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -3.13       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 19          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.021198772 |
# |    clip_fraction        | 0.245       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.87       |
# |    explained_variance   | -0.0265     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0587     |
# |    value_loss           | 5.17        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.5       |
# |    ep_rew_mean          | -2.14      |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 20         |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.02317185 |
# |    clip_fraction        | 0.265      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.0582     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.76       |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0601    |
# |    value_loss           | 4.98       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | -1.97       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 21          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.023664542 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.104       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.97        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.068      |
# |    value_loss           | 4.99        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -2          |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 22          |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.023082525 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.131       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.84        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.064      |
# |    value_loss           | 4.94        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -2.12       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 23          |
# |    time_elapsed         | 318         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025189107 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.0565      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0625     |
# |    value_loss           | 4.57        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -1.4        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 24          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.026352488 |
# |    clip_fraction        | 0.287       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.66       |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0646     |
# |    value_loss           | 4.38        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | -2.38       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 25          |
# |    time_elapsed         | 348         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.027209718 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.48        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0667     |
# |    value_loss           | 4.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.3        |
# |    ep_rew_mean          | -1.31       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 26          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.022199452 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0602     |
# |    value_loss           | 4.9         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.7        |
# |    ep_rew_mean          | -0.84       |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 27          |
# |    time_elapsed         | 376         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.023119144 |
# |    clip_fraction        | 0.266       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.0223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.06        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0576     |
# |    value_loss           | 5.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | -0.31       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 28          |
# |    time_elapsed         | 388         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.028178085 |
# |    clip_fraction        | 0.316       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.54       |
# |    explained_variance   | 0.2         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.54        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0653     |
# |    value_loss           | 4.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.6       |
# |    ep_rew_mean          | -1.24      |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 29         |
# |    time_elapsed         | 403        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02361814 |
# |    clip_fraction        | 0.268      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.295      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.42       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0607    |
# |    value_loss           | 4.63       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.4        |
# |    ep_rew_mean          | -1.69       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 30          |
# |    time_elapsed         | 417         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.025346052 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.064      |
# |    value_loss           | 4.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 0.03        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 31          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.027173044 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.93        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0638     |
# |    value_loss           | 4.49        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | -0.34       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 32          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.022796758 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.69        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0626     |
# |    value_loss           | 4.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 0.38        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 33          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.027085189 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.38       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0619     |
# |    value_loss           | 5.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | 0.88        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 34          |
# |    time_elapsed         | 475         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.027727481 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.1         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0644     |
# |    value_loss           | 4.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.8        |
# |    ep_rew_mean          | -0.48       |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 35          |
# |    time_elapsed         | 487         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.025165152 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0608     |
# |    value_loss           | 4.01        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11         |
# |    ep_rew_mean          | 0.04       |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 36         |
# |    time_elapsed         | 502        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.02870385 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.27      |
# |    explained_variance   | 0.223      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4        |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0662    |
# |    value_loss           | 4.29       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 0.16        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 37          |
# |    time_elapsed         | 515         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.026139997 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0637     |
# |    value_loss           | 4.09        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10.6       |
# |    ep_rew_mean          | 0.17       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 38         |
# |    time_elapsed         | 527        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.02828174 |
# |    clip_fraction        | 0.302      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.22      |
# |    explained_variance   | 0.225      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.99       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0589    |
# |    value_loss           | 4.37       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 0.43        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 39          |
# |    time_elapsed         | 541         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.027290203 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.17        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0584     |
# |    value_loss           | 3.97        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 0.28        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 40          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.027852925 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0592     |
# |    value_loss           | 3.98        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.4        |
# |    ep_rew_mean          | 0.95        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 41          |
# |    time_elapsed         | 569         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.025857233 |
# |    clip_fraction        | 0.268       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 5.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | 0.13        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 42          |
# |    time_elapsed         | 583         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024677195 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0604     |
# |    value_loss           | 4.48        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11         |
# |    ep_rew_mean          | 0.49       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 43         |
# |    time_elapsed         | 596        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.02709015 |
# |    clip_fraction        | 0.283      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.13      |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.05       |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0574    |
# |    value_loss           | 5.16       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | 0.66        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 44          |
# |    time_elapsed         | 611         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.024246007 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0532     |
# |    value_loss           | 5.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.4       |
# |    ep_rew_mean          | 0.6        |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 45         |
# |    time_elapsed         | 627        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.02819416 |
# |    clip_fraction        | 0.297      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.269      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.63       |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.062     |
# |    value_loss           | 4.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.1        |
# |    ep_rew_mean          | 0.76        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 46          |
# |    time_elapsed         | 641         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.029397741 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.8         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0574     |
# |    value_loss           | 4.83        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.7       |
# |    ep_rew_mean          | 1.05       |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 47         |
# |    time_elapsed         | 655        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.02977994 |
# |    clip_fraction        | 0.293      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2         |
# |    explained_variance   | 0.186      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.11       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0591    |
# |    value_loss           | 4.67       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | 1.6         |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 48          |
# |    time_elapsed         | 669         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.026418496 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.55        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.06       |
# |    value_loss           | 5.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | 1.01        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 49          |
# |    time_elapsed         | 684         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.028371006 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.345       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0629     |
# |    value_loss           | 3.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 1.51        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 50          |
# |    time_elapsed         | 699         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.028491264 |
# |    clip_fraction        | 0.273       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.41        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0578     |
# |    value_loss           | 3.92        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.3       |
# |    ep_rew_mean          | 1.09       |
# | time/                   |            |
# |    fps                  | 146        |
# |    iterations           | 51         |
# |    time_elapsed         | 714        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.02663391 |
# |    clip_fraction        | 0.278      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.94      |
# |    explained_variance   | 0.324      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.36       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.06      |
# |    value_loss           | 4.34       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.9        |
# |    ep_rew_mean          | 1.32        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 52          |
# |    time_elapsed         | 729         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.026824232 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.429       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.66        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0567     |
# |    value_loss           | 3.96        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | 2.07       |
# | time/                   |            |
# |    fps                  | 145        |
# |    iterations           | 53         |
# |    time_elapsed         | 744        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.03056719 |
# |    clip_fraction        | 0.288      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.9       |
# |    explained_variance   | 0.283      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.55       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0596    |
# |    value_loss           | 4.06       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.4        |
# |    ep_rew_mean          | 1           |
# | time/                   |             |
# |    fps                  | 145         |
# |    iterations           | 54          |
# |    time_elapsed         | 761         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.027045686 |
# |    clip_fraction        | 0.257       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.29        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0592     |
# |    value_loss           | 3.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11          |
# |    ep_rew_mean          | 0.42        |
# | time/                   |             |
# |    fps                  | 144         |
# |    iterations           | 55          |
# |    time_elapsed         | 778         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.027777353 |
# |    clip_fraction        | 0.27        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.16        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0613     |
# |    value_loss           | 4.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.4        |
# ...
# |    approx_kl            | 0.046145253 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.447      |
# |    explained_variance   | 0.313       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 24230       |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 6.11        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 11.8      |
# |    ep_rew_mean          | 4.48      |
# | time/                   |           |
# |    fps                  | 296       |
# |    iterations           | 2425      |
# |    time_elapsed         | 16741     |
# |    total_timesteps      | 4966400   |
# | train/                  |           |
# |    approx_kl            | 0.0527806 |
# |    clip_fraction        | 0.178     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.447    |
# |    explained_variance   | 0.373     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.41      |
# |    n_updates            | 24240     |
# |    policy_gradient_loss | -0.032    |
# |    value_loss           | 7.81      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.3       |
# |    ep_rew_mean          | 3.25       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2426       |
# |    time_elapsed         | 16748      |
# |    total_timesteps      | 4968448    |
# | train/                  |            |
# |    approx_kl            | 0.06355935 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.439     |
# |    explained_variance   | 0.467      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.83       |
# |    n_updates            | 24250      |
# |    policy_gradient_loss | -0.0328    |
# |    value_loss           | 5.61       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.1       |
# |    ep_rew_mean          | 2.55       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2427       |
# |    time_elapsed         | 16755      |
# |    total_timesteps      | 4970496    |
# | train/                  |            |
# |    approx_kl            | 0.05852235 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.452     |
# |    explained_variance   | 0.544      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.35       |
# |    n_updates            | 24260      |
# |    policy_gradient_loss | -0.0346    |
# |    value_loss           | 4.42       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.3        |
# |    ep_rew_mean          | 3.43        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2428        |
# |    time_elapsed         | 16764       |
# |    total_timesteps      | 4972544     |
# | train/                  |             |
# |    approx_kl            | 0.061349902 |
# |    clip_fraction        | 0.23        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.436      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.31        |
# |    n_updates            | 24270       |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 3.67        |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 12       |
# |    ep_rew_mean          | 3.82     |
# | time/                   |          |
# |    fps                  | 296      |
# |    iterations           | 2429     |
# |    time_elapsed         | 16773    |
# |    total_timesteps      | 4974592  |
# | train/                  |          |
# |    approx_kl            | 0.08029  |
# |    clip_fraction        | 0.173    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.446   |
# |    explained_variance   | 0.353    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.79     |
# |    n_updates            | 24280    |
# |    policy_gradient_loss | -0.029   |
# |    value_loss           | 9.73     |
# --------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 3.95        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2430        |
# |    time_elapsed         | 16782       |
# |    total_timesteps      | 4976640     |
# | train/                  |             |
# |    approx_kl            | 0.054992497 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.25        |
# |    n_updates            | 24290       |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 6.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.3       |
# |    ep_rew_mean          | 3.56       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2431       |
# |    time_elapsed         | 16790      |
# |    total_timesteps      | 4978688    |
# | train/                  |            |
# |    approx_kl            | 0.09372377 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.435     |
# |    explained_variance   | 0.443      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.2        |
# |    n_updates            | 24300      |
# |    policy_gradient_loss | -0.0303    |
# |    value_loss           | 4.34       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.6       |
# |    ep_rew_mean          | 2.8        |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2432       |
# |    time_elapsed         | 16798      |
# |    total_timesteps      | 4980736    |
# | train/                  |            |
# |    approx_kl            | 0.06294669 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.444     |
# |    explained_variance   | 0.634      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.941      |
# |    n_updates            | 24310      |
# |    policy_gradient_loss | -0.0347    |
# |    value_loss           | 3.02       |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 16.4     |
# |    ep_rew_mean          | -11.7    |
# | time/                   |          |
# |    fps                  | 296      |
# |    iterations           | 2433     |
# |    time_elapsed         | 16805    |
# |    total_timesteps      | 4982784  |
# | train/                  |          |
# |    approx_kl            | 2.510456 |
# |    clip_fraction        | 0.207    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.405   |
# |    explained_variance   | 0.217    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 2.16     |
# |    n_updates            | 24320    |
# |    policy_gradient_loss | -0.0471  |
# |    value_loss           | 36.8     |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.8       |
# |    ep_rew_mean          | 4.57       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2434       |
# |    time_elapsed         | 16813      |
# |    total_timesteps      | 4984832    |
# | train/                  |            |
# |    approx_kl            | 0.18247308 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.455     |
# |    explained_variance   | 0.211      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.59       |
# |    n_updates            | 24330      |
# |    policy_gradient_loss | -0.0679    |
# |    value_loss           | 45.9       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 11.5       |
# |    ep_rew_mean          | 3.34       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2435       |
# |    time_elapsed         | 16823      |
# |    total_timesteps      | 4986880    |
# | train/                  |            |
# |    approx_kl            | 0.07433376 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.455     |
# |    explained_variance   | 0.487      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.19       |
# |    n_updates            | 24340      |
# |    policy_gradient_loss | -0.0329    |
# |    value_loss           | 3.1        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.8        |
# |    ep_rew_mean          | 4.56        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2436        |
# |    time_elapsed         | 16831       |
# |    total_timesteps      | 4988928     |
# | train/                  |             |
# |    approx_kl            | 0.037963934 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16        |
# |    n_updates            | 24350       |
# |    policy_gradient_loss | -0.0276     |
# |    value_loss           | 4.87        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.5        |
# |    ep_rew_mean          | 3.97        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2437        |
# |    time_elapsed         | 16838       |
# |    total_timesteps      | 4990976     |
# | train/                  |             |
# |    approx_kl            | 0.056896903 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58        |
# |    n_updates            | 24360       |
# |    policy_gradient_loss | -0.0305     |
# |    value_loss           | 3.54        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 11.6      |
# |    ep_rew_mean          | 3.54      |
# | time/                   |           |
# |    fps                  | 296       |
# |    iterations           | 2438      |
# |    time_elapsed         | 16846     |
# |    total_timesteps      | 4993024   |
# | train/                  |           |
# |    approx_kl            | 2.4870102 |
# |    clip_fraction        | 0.44      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.299    |
# |    explained_variance   | 0.138     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 11.3      |
# |    n_updates            | 24370     |
# |    policy_gradient_loss | -0.0909   |
# |    value_loss           | 105       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.7        |
# |    ep_rew_mean          | 4.01        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2439        |
# |    time_elapsed         | 16855       |
# |    total_timesteps      | 4995072     |
# | train/                  |             |
# |    approx_kl            | 0.078135714 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.481       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4         |
# |    n_updates            | 24380       |
# |    policy_gradient_loss | -0.0353     |
# |    value_loss           | 4.67        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 4.69        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2440        |
# |    time_elapsed         | 16862       |
# |    total_timesteps      | 4997120     |
# | train/                  |             |
# |    approx_kl            | 0.067742646 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.23        |
# |    n_updates            | 24390       |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 3.46        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12         |
# |    ep_rew_mean          | 2.42       |
# | time/                   |            |
# |    fps                  | 296        |
# |    iterations           | 2441       |
# |    time_elapsed         | 16869      |
# |    total_timesteps      | 4999168    |
# | train/                  |            |
# |    approx_kl            | 0.05071391 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.446     |
# |    explained_variance   | 0.632      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.65       |
# |    n_updates            | 24400      |
# |    policy_gradient_loss | -0.0325    |
# |    value_loss           | 3.56       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.3        |
# |    ep_rew_mean          | 3.43        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2442        |
# |    time_elapsed         | 16877       |
# |    total_timesteps      | 5001216     |
# | train/                  |             |
# |    approx_kl            | 0.028265957 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 24410       |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 12.4        |
# -----------------------------------------

# %%
model.save("ppo_5mil")

# %%
model_1 = PPO.load("ppo_5mil",env =env1)
percentage,mean_reward = accuracy_fn(model_1,env1)
print("Success rate:",percentage)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Success rate: 0.0

# %% [markdown]
# I actually trained it for 5 million timesteps and random words too. It didn't have the desired accuracy on even the training set either.

# %% [markdown]
# #### Approach 2
# We now think about using imitation learning to guess the word. I have used the following [github repository](https://github.com/YAPhoa/HangmanKeras.git) for reference. The changes i made to the code given there is make the network in pytorch instead of keras which decreased the training time by more than 10 times. I also made minor changes to the classes to decrease the training time even further

# %%
class Hangman:
    def __init__(self, words, max_tries = 6 ) :
        self.words = words
        self.max_tries = max_tries
        
    def reset(self) :
        self.tries_remaining = self.max_tries
        self.word = np.random.choice(self.words)
        self.obscurred_word = [27 for i in range(len(self.word))]
        self.guessed = set()
        self.correct_guesses = 0
        return self.obscurred_word
        
    def step(self, letter) :
        if letter not in self.guessed :
            self.guessed.add(letter)
        else :
            return self.obscurred_word, False, {}

        if letter in self.word :
            for i in range(len(self.word)) :
                if letter == self.word[i] :
                    self.obscurred_word[i] = ord(letter)-ord('a')+1
                    self.correct_guesses += 1
            if self.correct_guesses == len(self.word):
                return self.obscurred_word,True, {'ans' : self.word}
            else :                
                return self.obscurred_word,False,{}
        else :
            self.tries_remaining -= 1
            if self.tries_remaining == 0 :
                return self.obscurred_word,True, {'ans' : self.word}
            else :
                return self.obscurred_word,False,{}

# %%
from warnings import filterwarnings

filterwarnings('ignore')

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from tensorflow.keras.utils import pad_sequences

# %%
class StateEmbedding(nn.Module):
    def __init__(self, maxlen=29):
        super(StateEmbedding, self).__init__()
        self.embedding = nn.Embedding(30, 100, padding_idx=0)
        self.lstm1 = nn.LSTM(100, 100, num_layers=2,batch_first=True, bidirectional=True,dropout=0.2,bias=False)
        self.drp = nn.Dropout(0.2)
        self.pool = nn.AdaptiveAvgPool1d(1)
        self.dense = nn.Linear(200, 100)
    
    def forward(self, x):
        x = self.embedding(x)
        x, _ = self.lstm1(x)
        x = self.drp(x)
        x = x.permute(0, 2, 1)
        x = self.pool(x).squeeze(2)
        x = torch.tanh(self.dense(x))
        return x

class GuessedEmbedding(nn.Module):
    def __init__(self):
        super(GuessedEmbedding, self).__init__()
        self.dense1 = nn.Linear(26, 60)
        self.dense2 = nn.Linear(60, 60)
    
    def forward(self, x):
        x = torch.tanh(self.dense1(x))
        x = torch.tanh(self.dense2(x))
        return x

class Network(nn.Module):
    def __init__(self, maxlen=29):
        super(Network, self).__init__()
        self.state_embedding = StateEmbedding(maxlen)
        self.guessed_embedding = GuessedEmbedding()
        self.dense1 = nn.Linear(160, 100)
        self.dense2 = nn.Linear(100, 26)
        self.compile()
    
    def forward(self, state, guessed):
        state = torch.tensor(state, dtype=torch.long)
        guessed = torch.tensor(guessed, dtype=torch.float)
        state_emb = self.state_embedding(state)
        guessed_emb = self.guessed_embedding(guessed)
        x = torch.cat((state_emb, guessed_emb), dim=1)
        x = torch.tanh(self.dense1(x))
        x = self.dense2(x)
        return x

    def compile(self, lr=1e-3):
        self.optimizer = optim.Adam(self.parameters(), lr=lr)
        self.loss_fn = nn.CrossEntropyLoss()
    
    def save(self, path='model.pth'):
        torch.save(self.state_dict(), path)
    
    def load(self, path='model.pth'):
        self.load_state_dict(torch.load(path))

class Agent(object) :

    def __init__(self, model) :
        self.guessed = set()
        self.model = model

    def select_action(self,state) :            
        probs = self.get_probs(state)
        i = 1
        sorted_probs = probs.argsort()
        while chr(sorted_probs[-i]+ord('a')) in self.guessed :
            i+= 1
        idx = sorted_probs[-i]
        guess = chr(idx+ord('a'))
        if guess not in self.guessed :
            self.guessed.add(guess)
        return guess

class NNAgent(Agent) :
    def __init__(self, model) :
        super().__init__(model)
        self.episode_memory = []
        self.states_history = []

    def train_model(self):
        inp_1, inp_2, obj = zip(*self.states_history)
        inp_1 = np.vstack(list(inp_1)).astype(float)
        inp_2 = np.vstack(list(inp_2)).astype(float)
        obj = np.vstack(list(obj)).astype(float)
        self.model.train()
        inp_1 = torch.tensor(inp_1,dtype=torch.long)
        inp_2 = torch.tensor(inp_2,dtype=torch.float)
        obj = torch.tensor(obj,dtype=torch.float)
        y = self.model(inp_1,inp_2)
        loss = self.model.loss_fn(y,obj)
        self.model.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.model.parameters(), 1)
        self.model.optimizer.step()
        self.states_history = []
        return loss

    def get_probs(self, state) :
        state = np.array(state).reshape(1,len(state))
        state = pad_sequences(state, maxlen = 29).reshape(1,29)
        guessed = np.array([1 if chr(i+ord('a')) in self.guessed else 0 for i in range(26)]).reshape(1,26)
        self.episode_memory.append((state,guessed))
        probs = self.model(state,guessed)
        probs = (torch.softmax(probs,dim=1)).squeeze()
        return probs

    def finalize_episode(self, answer) :
        inp_1, inp_2 = zip(*self.episode_memory)
        inp_1 = np.vstack(list(inp_1)).astype(float)      #stack the game state matrix
        inp_2 = np.vstack(list(inp_2)).astype(float)      #stack the one hot-encoded guessed matrix
        obj = 1.0 - inp_2                                 #compute the unused letters one-hot encoded
        len_ep = len(self.episode_memory)                 #length of episode
        correct_mask = np.array([[1 if chr(i+ord('a')) in answer else 0 for i in range(26)]]) # get mask from correct answer
        correct_mask = np.repeat(correct_mask, len_ep, axis = 0).astype(float)
        obj = correct_mask * obj  #the correct action is choosing the letters that are both unused AND exist in the word
        obj /= obj.sum(axis = 1).reshape(-1,1) #normalize so it sums to one
        self.states_history.append((inp_1, inp_2,obj))
        self.episode_memory = []
        self.guessed = set()

# %%
policy_net = Network()
player = NNAgent(policy_net)

save_episode = 500
view_episode = 100
update_episode = 5
avg_correct = 0
wins_avg = 0
n_trials = 20000
progbar = tqdm(range(n_trials))

""" 
Warmup Phase
Since the network can only collect data by interacting with the environment, 
to collect more data max_lives parameter or the maximum number of trial before game over is set 
slightly extra than the actual game parameter so episodes are longer. 
"""

game_params = {'max_tries' : 8}
env = Hangman(word_list, **game_params)

print('Training Start ...', end = '\n\n')

for episode_set in progbar :
    for _ in range(update_episode) :
        state = env.reset()
        done = False
        correct_count = 0
        while not done :
            guess = player.select_action(state)
            state, done, ans = env.step(guess)
        if env.correct_guesses == len(env.word):
            wins_avg += 1.0
        player.finalize_episode(ans['ans'])
        avg_correct += correct_count
    loss = player.train_model()
    progbar.set_description("Loss : {:.3f}              ".format(loss))

    if (episode_set +1) % view_episode == 0 :
        views = (episode_set + 1,avg_correct/(update_episode*view_episode), view_episode*update_episode, wins_avg/(update_episode*view_episode))
        print('Episode {} -------- Average Correct Count : {:.3f}     Last {} winrate : {:.3f}'.format(*views))
        if loss is not None :
            print('Loss :', loss)
            print()
            avg_correct = 0
            wins_avg = 0

    if (episode_set +1) % save_episode == 0 :
        player.model.save('model.pth')

print()
game_params = {'max_tries' : 6}
env = Hangman(word_list, **game_params)

n_trials = 70000
progbar = tqdm(range(n_trials))

for episode_set in progbar :
    for _ in range(update_episode) :
        total_reward = 0    
        state = env.reset()
        done = False
        correct_count = 0
        while not done :
            guess = player.select_action(state)
            state, done, ans = env.step(guess)
        if env.correct_guesses == len(env.word):
            wins_avg += 1.0
        player.finalize_episode(ans['ans'])
        avg_correct += correct_count
    loss = player.train_model()
    progbar.set_description("Loss : {:.3f}              ".format(loss))

    if (episode_set +1) % view_episode == 0 :
        views = (episode_set + 1,avg_correct/(update_episode*view_episode), view_episode, wins_avg/(update_episode*view_episode))
        print('Episode {} -------- Average Correct Count : {:.3f}     Last {} winrate : {:.3f}'.format(*views))
        if loss is not None :
            print('Loss :', loss)
            print()
            avg_correct = 0
            wins_avg = 0

    if (episode_set +1) % save_episode == 0 :
        player.model.save('model.pth')
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# Training Start ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[118], line 30
#      28 correct_count = 0
#      29 while not done :
# ---> 30     guess = player.select_action(state)
#      31     state, done, ans = env.step(guess)
#      32 if env.correct_guesses == len(env.word):
#
# Cell In[117], line 66, in Agent.select_action(self, state)
#      65 def select_action(self,state) :
# ---> 66     probs = self.get_probs(state)
#      67     i = 1
#      68     sorted_probs = probs.argsort()
#
# Cell In[117], line 106, in NNAgent.get_probs(self, state)
#     104 guessed = np.array([1 if chr(i+ord('a')) in self.guessed else 0 for i in range(26)]).reshape(1,26)
#     105 self.episode_memory.append((state,guessed))
# --> 106 probs = self.model(state,guessed)
#     107 probs = (torch.softmax(probs,dim=1)).squeeze()
#     108 return probs
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[117], line 42, in Network.forward(self, state, guessed)
#      40 state = torch.tensor(state, dtype=torch.long)
#      41 guessed = torch.tensor(guessed, dtype=torch.float)
# ---> 42 state_emb = self.state_embedding(state)
#      43 guessed_emb = self.guessed_embedding(guessed)
#      44 x = torch.cat((state_emb, guessed_emb), dim=1)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[117], line 14, in StateEmbedding.forward(self, x)
#      12 x, _ = self.lstm1(x)
#      13 x = self.drp(x)
# ---> 14 x = x.permute(0, 2, 1)
#      15 x = self.pool(x).squeeze(2)
#      16 x = torch.tanh(self.dense(x))
#
# KeyboardInterrupt:

# %%
guessed_letters = set()
policy = Network()
policy.load_state_dict(torch.load("model.pth"))
policy.eval()

def guess(self, word):
    len_word = len(word)
    state = np.array([ord(c)-ord('a')+1 if c != "_" else 27 for c in word])
    state = (pad_sequences([state],maxlen=29)).reshape(1,29)
    guessed = np.array([1 if chr(i+ord('a')) in self.guessed_letters else 0 for i in range(26)]).reshape(1,26)
    probs = torch.softmax(self.policy(state,guessed),dim=1).squeeze()
    i = 1
    sorted_probs = probs.argsort()
    while chr(sorted_probs[-i]+ord('a')) in self.guessed_letters :
        i+= 1
    idx = sorted_probs[-i]
    guess = chr(idx+ord('a'))
    guessed_letters.add(guess)
    return guess
